# %%
# %pylab inline #用這個代表python會數學
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([3,4,5,6,1,2,3])

# %%
plot(randn(100))

# %%
plot([-2,4,7,9,10], [3,7,2,9,7])

# %% [markdown]
# 在上面把模式改成markdown就可以做筆記
# ＃ 標題    ＃＃ 次標題  以此類推。
#
#
# 如果要分項說明，加上＊在前面
# （不管是＃或是＊都是要用英文的）
#
#
# 如果是要連結：
# [網址的名字](放上網址)
#
#
# 如果是要插入圖片：
# ![圖片的名字](圖片再jupyter notebook裡面的網址)
#
#
# 如果要打數學符號：
#
# １隨文模式：
#
#   假設有一個方程式: f(x) = x^3 - 2x^2 + 5 ，如果要他印出來漂亮就在方程式頭尾加上$的符號
#
#   $f(x) = x^3 - 2x^2 + 5$
#
# 2 展示模式：
#
#   在頭尾加上$$兩個符號，方程式就繪置中
#
#   $$f(x) = x^3 - 2x^2 + 5$$
#
#
# Python的變數可以用中文命名
#
#
# 三個引號可以換行'''然後後面打要打的字，用一般的換行換，印出來就會換行了
#
#
# 如果要重複print 字串 就直接 數字＊字串
#
#
# Python如果要轉換型態，要括號後面要轉的東西 ex. a = int (message)

# %% [markdown]
# # input指令(就是java的scanner)
# ## (得到的結果會是字串）

# %%
a = input('Enter a number:')
# Out:
# Enter a number:3

# %%
print(a)
# Out:
# 3
